# %% [markdown]
# ## Seaborn is a visualization library that is built on top of matplotlib
#
# ## Seaborn is open source and is hosted on github, the official documentation page can be found on github, to find the seaborn documentation, just search on google.
#
# ### You will find the link to the API and gallery page on the github page

# %% [markdown]
# # DISTRIBUTION PLOTS

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#distplot helps to show the distribution of a univariate set of observations
#essentially a histogram

sns.distplot(tips['total_bill'])
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(tips['total_bill'], kde=False,bins=30)
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill', y='tip',data=tips)
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill', y='tip',data=tips, kind='hex')

# The kind argument takes hex to convert the default scatter plot to hexagonal plots
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill', y='tip',data=tips, kind='reg')

#Using kind as reg tries to fit a regression line to the scatter plot
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill', y='tip',data=tips, kind='kde')

#The kind as kde represents Kernel Density

# %%
sns.pairplot(tips, hue='sex')#palette='coolwarm'#)

#plots every single combination of the numerical columns in the dataframe
#plots a histogram when it wants to plot a variable against itself
#The 'hue' argument allows you to pass in any categorical(non-numerical) column,
#the blue points are male while the orange ones are male
#the palette argument allows us ti chnage the colours of our data the way we want to

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# # KDE plots stand for Kernel Density Estimation plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5,0.98,'Sum of the Basis Functions')

# %% [markdown]
# # CATEGORIAL PLOTS

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

#Barplot shows the relationship between two categorical features in repect to a target variable

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator=np.std)

#The estimator argument can take a value you choose, in this case we are looking at the standard deviation

# %%
#A countplot in seaborn is essentially the same as a barplot except the estimator is explicitly
#counting the number of occurences

#This is essentially the same as a barplot except that the 'y' axis has been chosen for you.

sns.countplot(x='sex', data =tips)

# %% [markdown]
# # BOX AND WHISKERPLOT
#
# ### This type of plot is often used to show the distribution of categorical data
# ### often used to show comparison between qualitative data

# %%
sns.boxplot(x='day',y='total_bill', data=tips )

#The box shows the plot while the whiskers extend to show the rest of the distrubtion
#The dots outside are basically outliers

# %%
sns.boxplot(x='day',y='total_bill', data=tips,hue='smoker' )

# %% [markdown]
# ## VIOLIN PLOT

# %%
sns.violinplot(x='day', y ='total_bill', data = tips)

# %%
sns.violinplot(x='day',y='total_bill',data = tips,hue='sex',split='True')

# %%
sns.stripplot(x='day',y='total_bill', data=tips, jitter =True)

# %%
sns.swarmplot(x='day',y='total_bill', data=tips)

#Swarmplot seems to be a combination of the violin plot and the stripplot
#One draw back of swarm plot is the inability to give clear information across large data sets

# %%
#One good way to use the swarm plot is to us it together with the violin plot but one must be careful
#so as not to oversuse this as it packs in a ton of information

sns.violinplot(x='day', y ='total_bill', data = tips)
sns.swarmplot(x='day',y='total_bill', data=tips, color='white')

# %% [markdown]
# ## The most general way of doing all the plots we've done earlier is to use the factor plot and then specify the type of plot as a value in the kind argument.

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='violin')

# %% [markdown]
# # MATRIX PLOTS

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Heat maps are primary ways of showing matrix maps
# ### In order for heatmaps to work properly your data must already be in matrix form

# %%
tc = tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc, annot = True, cmap='coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp = flights.pivot_table(index='month', columns='year', values ='passengers')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp)

# %%
sns.heatmap(fp,cmap='magma')

# %%
#other arguments one can add to heatmap include linecolor, linewidths
sns.heatmap(fp,cmap='magma', linecolor='white', linewidths=4)

# %% [markdown]
# ### Another type of matrix map is the cluster map,
# ### Cluster map uses hierarichal clustering to produce a clustered version of the heatmap
# #### it basically tries to cluster rows and columns together based off their similarities

# %%
sns.clustermap(fp)

# %%
#To normalize this, just use the standard scale argument and pass in a value of 1
sns.clustermap(fp, cmap='coolwarm', standard_scale=1)

# %% [markdown]
# # RegressionPlots

# %%
#lm plot makes a simple linear model plot

sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'])

#hue helps to show categorical features
#You can add markers

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex', row='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', aspect=0.6, size=8)

#aspect changes the aspect and size changes the size

# %% [markdown]
# # GRID

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

g.map_diag(sns.distplot)

#Pairplot is a simplified version of pair grid
#Pair grid gives you a little bit more contol

# %%
g = sns.PairGrid(iris)
g.map_upper(plt.scatter)
g.map_diag(sns.distplot)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %% [markdown]
# # FACET GRIDS

# %%
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(sns.distplot,'total_bill')
# Out:
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\envs\Train\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
